# %% [markdown]
# # Task 1
#
# **This notebook does the following,**
#
# 1. Understand the input data and go through each column
# 2. Visualizes and Summarizes the data

# %% [markdown]
# ## Import Packages

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## Load Data

# %%
twitterdf = pd.read_json('~/Local/datasets/corona-out-3',lines = True)

# %%
twitterdf.describe()
# Out:
#                  id        id_str  in_reply_to_status_id  \
# count  1.019160e+05  1.019160e+05           1.361000e+04
# mean   1.254042e+18  1.254042e+18           1.253564e+18
# std    1.064351e+13  1.064351e+13           8.544387e+15
# min    1.254023e+18  1.254023e+18           8.218186e+17
# 25%    1.254033e+18  1.254033e+18           1.253953e+18
# 50%    1.254042e+18  1.254042e+18           1.254026e+18
# 75%    1.254051e+18  1.254051e+18           1.254041e+18
# max    1.254060e+18  1.254060e+18           1.254060e+18
#
#        in_reply_to_status_id_str  in_reply_to_user_id  \
# count               1.361000e+04         1.485500e+04
# mean                1.253564e+18         3.915265e+17
# std                 8.544387e+15         5.177342e+17
# min                 8.218186e+17         3.987000e+03
# 25%                 1.253953e+18         1.454341e+08
# 50%                 1.254026e+18         1.866939e+09
# 75%                 1.254041e+18         9.824704e+17
# ...

# %%
twitterdf.isna().sum()
# Out:
# created_at                        0
# id                                0
# id_str                            0
# text                              0
# display_text_range            83792
# source                            0
# truncated                         0
# in_reply_to_status_id         88306
# in_reply_to_status_id_str     88306
# in_reply_to_user_id           87061
# in_reply_to_user_id_str       87061
# in_reply_to_screen_name       87061
# user                              0
# geo                          101839
# coordinates                  101839
# place                        100545
# contributors                 101916
# is_quote_status                   0
# quote_count                       0
# reply_count                       0
# retweet_count                     0
# favorite_count                    0
# entities                          0
# extended_entities             94649
# favorited                         0
# retweeted                         0
# ...

# %% [markdown]
# ## Top tweet languages

# %%
twitterdf.lang
# Out:
#                       created_at                   id               id_str  \
# 0      2020-04-25 12:21:41+00:00  1254022770679320576  1254022770679320576
# 1      2020-04-25 12:21:41+00:00  1254022770746372096  1254022770746372096
# 2      2020-04-25 12:21:42+00:00  1254022772558368768  1254022772558368768
# 3      2020-04-25 12:21:42+00:00  1254022772575043586  1254022772575043584
# 4      2020-04-25 12:21:42+00:00  1254022772877131777  1254022772877131776
# ...                          ...                  ...                  ...
# 101911 2020-04-25 14:48:38+00:00  1254059751379361793  1254059751379361792
# 101912 2020-04-25 14:48:38+00:00  1254059751949942784  1254059751949942784
# 101913 2020-04-25 14:48:38+00:00  1254059752134455296  1254059752134455296
# 101914 2020-04-25 14:48:38+00:00  1254059751945596930  1254059751945596928
# 101915 2020-04-25 14:48:38+00:00  1254059752201519104  1254059752201519104
#
# ...

# %%
twitterdf.dtypes
# Out:
# created_at                   datetime64[ns, UTC]
# id                                         int64
# id_str                                     int64
# text                                      object
# display_text_range                        object
# source                                    object
# truncated                                   bool
# in_reply_to_status_id                    float64
# in_reply_to_status_id_str                float64
# in_reply_to_user_id                      float64
# in_reply_to_user_id_str                  float64
# in_reply_to_screen_name                   object
# user                                      object
# geo                                       object
# coordinates                               object
# place                                     object
# contributors                             float64
# is_quote_status                             bool
# quote_count                                int64
# ...
